# %%
import pandas as pd
import requests

# %%
r = requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')
data = r.json()
df = pd.DataFrame(data=data)
df.head()
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# ...

# %%
df.describe()
# Out:
#                              time  \
# count                           3
# unique                          3
# top     Jun 18, 2023 22:19:00 UTC
# freq                            1
#
#                                                disclaimer chartName  \
# count                                                   6         6
# unique                                                  1         1
# top     This data was produced from the CoinDesk Bitco...   Bitcoin
# freq                                                    6         6
#
#                                                       bpi
# count                                                   3
# unique                                                  3
# top     {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# freq                                                    1

# %%
df.shape
# Out:
# (6, 4)

# %%
df[df['time'] == '2']
# Out:
# Empty DataFrame
# Columns: [time, disclaimer, chartName, bpi]
# Index: []

# %%
df[['disclaimer','bpi']].head()
# Out:
#                                                    disclaimer  \
# updated     This data was produced from the CoinDesk Bitco...
# updatedISO  This data was produced from the CoinDesk Bitco...
# updateduk   This data was produced from the CoinDesk Bitco...
# USD         This data was produced from the CoinDesk Bitco...
# GBP         This data was produced from the CoinDesk Bitco...
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# USD         {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# GBP         {'code': 'GBP', 'symbol': '&pound;', 'rate': '...

# %%
df.iloc[2:9]
# Out:
#                                 time  \
# updateduk  Jun 18, 2023 at 23:19 BST
# USD                              NaN
# GBP                              NaN
# EUR                              NaN
#
#                                                   disclaimer chartName  \
# updateduk  This data was produced from the CoinDesk Bitco...   Bitcoin
# USD        This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP        This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR        This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                          bpi
# updateduk                                                NaN
# USD        {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# GBP        {'code': 'GBP', 'symbol': '&pound;', 'rate': '...
# EUR        {'code': 'EUR', 'symbol': '&euro;', 'rate': '2...

# %%
df[df['chartName'] == 'Bitcoin']
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
df[['time','bpi']].head()
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# USD         {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# GBP         {'code': 'GBP', 'symbol': '&pound;', 'rate': '...

# %%
df.iloc[1:3]
# Out:
#                                  time  \
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
#
#                                                    disclaimer chartName  bpi
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin  NaN
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin  NaN

# %%
df['chartName']
# Out:
# updated       Bitcoin
# updatedISO    Bitcoin
# updateduk     Bitcoin
# USD           Bitcoin
# GBP           Bitcoin
# EUR           Bitcoin
# Name: chartName, dtype: object

# %%
df[['bpi']]
# Out:
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# USD         {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# GBP         {'code': 'GBP', 'symbol': '&pound;', 'rate': '...
# EUR         {'code': 'EUR', 'symbol': '&euro;', 'rate': '2...

# %%
df.iloc[:, -1]
# Out:
# updated                                                     NaN
# updatedISO                                                  NaN
# updateduk                                                   NaN
# USD           {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
# GBP           {'code': 'GBP', 'symbol': '&pound;', 'rate': '...
# EUR           {'code': 'EUR', 'symbol': '&euro;', 'rate': '2...
# Name: bpi, dtype: object

# %%
#select columns in index positions
df_new = df.iloc[:, [0,1,3]]
df_new
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer  \
# updated     This data was produced from the CoinDesk Bitco...
# updatedISO  This data was produced from the CoinDesk Bitco...
# updateduk   This data was produced from the CoinDesk Bitco...
# USD         This data was produced from the CoinDesk Bitco...
# GBP         This data was produced from the CoinDesk Bitco...
# EUR         This data was produced from the CoinDesk Bitco...
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# ...

# %%
#select columns in index range
df_new = df.iloc[:, 0:3]
df_new
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin

# %%
#select columns called 
df_new = df [ ['time', 'disclaimer']]
df_new
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer
# updated     This data was produced from the CoinDesk Bitco...
# updatedISO  This data was produced from the CoinDesk Bitco...
# updateduk   This data was produced from the CoinDesk Bitco...
# USD         This data was produced from the CoinDesk Bitco...
# GBP         This data was produced from the CoinDesk Bitco...
# EUR         This data was produced from the CoinDesk Bitco...

# %%
#select and print 4 rows in a pandas data frame
get_rows = df.head (4) 
print (get_rows)
# Out:
#                                  time  \
# updated     Jun 18, 2023 22:19:00 UTC
# updatedISO  2023-06-18T22:19:00+00:00
# updateduk   Jun 18, 2023 at 23:19 BST
# USD                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# updateduk                                                 NaN
# USD         {'code': 'USD', 'symbol': '&#36;', 'rate': '26...
